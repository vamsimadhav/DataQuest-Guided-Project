# %%
# Analyze App Store and Play Store trends to identify which app categories attract the largest user base, ultimately driving higher profits.

## The project here is about to identify the most hot / popular catogery's where the developer can add ad's to it to make revenue as we are looking for free apps

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    data_slice = dataset[start:end]
    for row in data_slice:
        print(row, end='\n')
        
    if rows_and_columns:
        print(len(dataset))
        print(len(dataset[0]))

# %%
from csv import reader
data_apple = open('AppleStore.csv')
data_google = open('googleplaystore.csv')

# %%
apple_data = reader(data_apple)
google_data = reader(data_google)

# %%
apple = list(apple_data)
google = list(google_data)

# %%
iOS = apple[1:]
android = google[1:]

# %%
explore_data(iOS,0,4, True)
explore_data(android,0,4, True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
# 7197
# 16
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
# ...

# %%
print(apple[0])
print(google[0])
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
### Determining the error in the Google Play Store Data

# %%
# Checking if the length of headers = length pf rows to find any discreapancy
for i in range(len(android)):
    row = android[i]
    if len(google[0]) != len(row):
        print(i)
# Out:
# 10472

# %%
del android[10472]

# %%
### Determining the duplicates from name in Android and actually checking if they are duplicates

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
unique_list = []
duplicate_list = []

for app in android:
    name = app[0]
    if name in unique_list:
        duplicate_list.append(name)
    else:
        unique_list.append(name)
        
print(unique_list)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'Coloring book moana', 'U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'Sketch - Draw & Paint', 'Pixel Draw - Number Art Coloring Book', 'Paper flowers instructions', 'Smoke Effect Photo Maker - Smoke Editor', 'Infinite Painter', 'Garden Coloring Book', 'Kids Paint Free - Drawing Fun', 'Text on Photo - Fonteee', 'Name Art Photo Editor - Focus n Filters', 'Tattoo Name On My Photo Editor', 'Mandala Coloring Book', '3D Color Pixel by Number - Sandbox Art Coloring', 'Learn To Draw Kawaii Characters', 'Photo Designer - Write your name with shapes', '350 Diy Room Decor Ideas', 'FlipaClip - Cartoon animation', 'ibis Paint X', 'Logo Maker - Small Business', "Boys Photo Editor - Six Pack & Men's Suit", 'Superheroes Wallpapers | 4K Backgrounds', 'Mcqueen Coloring pages', 'HD Mickey Minnie Wallpapers', 'Harley Quinn wallpapers HD', 'Colorfit - Drawing & Coloring', 'Animated Photo Editor', 'Pencil Sketch Drawing', 'Easy Realistic Drawing T
# ...

# %%
len(duplicate_list)
# Out:
# 1181

# %%
# For example in instagram we only see the reviews count as a diffrentiator in the list and everything else is anme in the eows

# %%
list_no_dup = {}

for app in android:
    name = app[0]
    review = float(app[3])
    
    if name in list_no_dup and review < list_no_dup[name]:
        list_no_dup[name] = review
    elif name not in list_no_dup:
        list_no_dup[name] = review

# %%
print(len(list_no_dup))
# Out:
# 9659

# %%
android_clean = []
already_added = []

# %%
for app in android:
    name = app[0]
    n_reviews = float(app[3])
    
    if (list_no_dup[name] == n_reviews) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name)

# %%
print(len(android_clean))
# Out:
# 9659

# %%
android_clean[0]
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook',
#  'ART_AND_DESIGN',
#  '4.1',
#  '159',
#  '19M',
#  '10,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Art & Design',
#  'January 7, 2018',
#  '1.0.0',
#  '4.0.3 and up']

# %%
def checkEnglishLanguage(val):
    count = 0
    for letter in val:
        if ord(letter) > 127:
            count += 1
    return False if count > 3 else True

# %%
print(checkEnglishLanguage('Instagram'))
print(checkEnglishLanguage('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(checkEnglishLanguage('Docs To Go™ Free Office Suite'))
print(checkEnglishLanguage('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %%
list_no_dup_ios = {}
for app in iOS:
    name_ios = app[1]
    review_ios = float(app[5])
    
    if name_ios in list_no_dup_ios and review_ios < list_no_dup_ios[name_ios]:
        list_no_dup_ios[name_ios] = review_ios
    elif name not in list_no_dup_ios:
        list_no_dup_ios[name_ios] = review_ios

# %%
iOS_clean = []

# %%
already_added_iOS = []
for app in iOS:
    name = app[1]
    n_reviews_ios = float(app[5])
    
    if (list_no_dup_ios[name] == n_reviews_ios) and (name not in already_added_iOS):
        iOS_clean.append(app)
        already_added_iOS.append(name)

# %%
# android removing non english apps
english_apps = []

for app in android_clean:
    name = app[0]
    if checkEnglishLanguage(name):
        english_apps.append(app)

# %%
print(len(english_apps))
# Out:
# 9614

# %%
# ios removing non english apps
english_apps_ios = []

for app in iOS_clean:
    name = app[1]
    if checkEnglishLanguage(name):
        english_apps_ios.append(app)

# %%
print(len(english_apps_ios))
# Out:
# 6181

# %%
free_android = []
for app in english_apps:
    price = app[7]
    if price == '0':
        free_android.append(app)
print(len(free_android))
# Out:
# 8862

# %%
free_ios = []
for app in english_apps_ios:
    price = app[4]
    if price == '0.0':
        free_ios.append(app)
print(len(free_ios))
# Out:
# 3220

# %%
def freq_table(dataset, index):
    dict = {}
    for app in dataset:
        if app[index] in dict:
            dict[app[index]] +=1
        elif app[index] not in dict:
            dict[app[index]] = 1
    return dict

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(free_ios,11)
print('/n')
display_table(free_android,9)
print('/n')
display_table(free_android,1)
# Out:
# Games : 1872
# Entertainment : 254
# Photo & Video : 160
# Education : 118
# Social Networking : 106
# Shopping : 84
# Utilities : 81
# Sports : 69
# Music : 66
# Health & Fitness : 65
# Productivity : 56
# Lifestyle : 51
# News : 43
# Travel : 40
# Finance : 36
# Weather : 28
# Food & Drink : 26
# Reference : 18
# Business : 17
# Book : 14
# Navigation : 6
# Medical : 6
# Catalogs : 4
# /n
# Tools : 747
# Entertainment : 538
# Education : 474
# Business : 406
# Productivity : 345
# Lifestyle : 345
# Finance : 328
# Medical : 313
# Sports : 307
# Personalization : 294
# Communication : 288
# Action : 275
# Health & Fitness : 272
# Photography : 261
# News & Magazines : 248
# Social : 236
# Travel & Local : 206
# Shopping : 199
# Books & Reference : 190
# Simulation : 181
# Dating : 165
# Arcade : 165
# Video Players & Editors : 158
# Casual : 155
# Maps & Navigation : 124
# Food & Drink : 110
# Puzzle : 100
# Racing : 88
# Role Playing : 83
# Libraries & Demo : 83
# ...

# %%
pg = display_table(free_ios,11)
# Out:
# Games : 1872
# Entertainment : 254
# Photo & Video : 160
# Education : 118
# Social Networking : 106
# Shopping : 84
# Utilities : 81
# Sports : 69
# Music : 66
# Health & Fitness : 65
# Productivity : 56
# Lifestyle : 51
# News : 43
# Travel : 40
# Finance : 36
# Weather : 28
# Food & Drink : 26
# Reference : 18
# Business : 17
# Book : 14
# Navigation : 6
# Medical : 6
# Catalogs : 4

# %%
for genere in pg:
    len_genre = 0
    total = 0
    for app in ios_free:
        genre_app = app[-5]
        if genre_app == genere:            
            n_ratings = float(app[5])
            total += n_ratings
            len_genre += 1
    avg_n_ratings = total / len_genre
